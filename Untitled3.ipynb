# %% [markdown]
# <a href="https://colab.research.google.com/github/l251030015-AlexPvr/Portafolio-Actividad/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
estatura=[1.82,1.78,1.81,1.60,1.57]
print("el cuarto elemento es:", estatura[3])
print("el ultimo elemento es:", estatura[-1])
for x in estatura:
  print(x)
sumatoria=0
for numero in estatura:
  sumatoria+=numero
print("suman todos",sumatoria)
# Out:
# el cuarto elemento es: 1.6
# el ultimo elemento es: 1.57
# 1.82
# 1.78
# 1.81
# 1.6
# 1.57
# suman todos 8.58

# %%
import numpy as np
calificaciones=np.array([70,85,92,100,75])
print(f"Arreglo original{calificaciones}")
# Out:
# Arreglo original[ 70  85  92 100  75]
